# %%
pip install SPARQLWrapper
# Out:
# Requirement already satisfied: SPARQLWrapper in /Users/onur/opt/anaconda3/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in /Users/onur/opt/anaconda3/lib/python3.9/site-packages (from SPARQLWrapper) (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /Users/onur/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/onur/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.4)
# Requirement already satisfied: six in /Users/onur/opt/anaconda3/lib/python3.9/site-packages (from isodate<0.7.0,>=0.6.0->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "http://onur-MacBook-Pro.local:7200/repositories/bacaksiz"
sparql = SPARQLWrapper(endpoint_url)

# %% [markdown]
# ## 1. Find all Authors.

# %%
# Define the SPARQL query
query1 = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?author ?name
WHERE {
  # ?author a ex:Author .
  # ?author foaf:name ?name .
}
"""

# Set the query and format
sparql.setQuery(query1)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Print the results directly
print("Author URI, Name")
for result in results["results"]["bindings"]:
    author = result["author"]["value"]
    name = result["name"]["value"]
    print(f"{author}, {name}")

print("Results have been printed.")
# Out:
# Author URI, Name
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2075376111, Yu Bao
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2249588356, Guosun Zeng
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1736546, Doina Caragea
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1932524, Xinming Ou
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_48691553, Su Zhang
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_143634612, G. Yin
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2109336475, Zhimin Zhang
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_38295334, Q. Song
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144625576, M. Barni
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1715407, A. Abrardo
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2488892, B. Tondi
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3192444, Kassem Kallas
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1717963, S. Rass
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_116879422, Yulyani Arifin
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_120647490, S. Henry
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1418344043, A. N. Yudhisthira
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_153316774, J. Andrew
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_70048683, S. D. Permai
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_113134742, Dietrich Squinkifer
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1390043728, Noah Wardrip-Fruin
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1394258787, Nick Junius
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144237889, Brent D. Hill
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2089829, Edward F. Melcer
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2877935, J. Ryan
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_46221898, M. Kreminski
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144508067, M. Zappalà
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145064289, A. Rao
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1873312, A. Chimirri
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1906922, Z. Debyser
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2105361, E. Clercq
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2324949, M. Barreca
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2558631, P. Monforte
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2584469, Cristina Gurnari
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2977596, B. V. Maele
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3058439, M. Witvrouw
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_36604738, L. Luca
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_90643212, J. Briggs
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2412024, S. Silakari
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_38534019, Neelu Nihalani
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_70205847, Mahesh Motwani
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1732285, Jason Begy
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_143989442, M. Specht
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1757996, R. Klemke
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2295803, M. Kalz
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2534790, Stefaan Ternier
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2625702, Birgit Schmitz
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1703130, T. Reps
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145190435, A. Bensoussan
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1773778, H. Tembine
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2059043, S. Yam
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3122645, Boualem Djehiche
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3386346, Ilchae Jung
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144971290, K. Yamane
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1832291, W. Takano
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2173160556, Yoshihiko Nakamura
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1393291803, T. Lowry
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145536002, Rajni Nigam
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145708964, G. Hayman
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1849436, M. Dwinell
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1916288, V. Petri
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2109448525, Shur-Jen Wang
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2109847248, Jennifer R. Smith
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_21744050, H. Jacob
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2474096, S. Laulederkind
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_4383002, M. Tutaj
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_47692442, M. Shimoyama
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_7144057, J. D. Pons
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_14454974, P. H. Seo
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_40030651, Bohyung Han
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_8511875, Jonghwan Mun
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_143906110, M. Holanda
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1803518, M. Brigido
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2057331457, M. E. Walter
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_31472189, Polyane Wercelens
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_39592606, Waldeyr M. C. Silva
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_70359360, S. Pill
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2110851001, Jim Brown
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_97213203, Marilyn L. Grechus
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_26591876, S. Velankar
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_47489005, M. Váradi
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2112851762, Jin Shi
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2285071262, Yin Lu
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1978719, V. Vesna
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1383246948, Sora Hayashi
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2113608835, Lin Meng
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2156211656, Mutsuki Tsuyama
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2328680, M. Masugi
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2719667, K. Saho
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2355912, C. V. Wangenheim
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3076734, A. Borgatto
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3082187, Rafael Savi
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145654328, P. Watson
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1728262, A. Negi
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2292166946, Kishore Kumar
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_118461124, Zafiri Makrina
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_35327641, S. Harkins
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_35510243, Martin W. P. Reid
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1684197, Y. Ioannidis
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2112820873, HaiBo Cui
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_49679382, Chuang Ma
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_6989114, Jingjing Zhai
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_11063801, Barry Liu
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1717955, James C. Lester
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1745330, Wookhee Min
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_34971293, Jonathan P. Rowe
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2825246, Yaroslav Ganin
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1768181, William van der Sterren
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1760762, B. Fung
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2119657963, Bowen Yang
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_4713365, F. Haghighat
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_95356210, K. Panchabikesan
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145696419, L. Sousa
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1765948, P. Trancoso
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1767172, A. Ilic
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1803904, Frederico Pratas
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3210937, S. Lessard
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144395551, M. Ivanović
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2025112, Z. Bosnić
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3113695, V. Kurbalija
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_51480852, Iztok Oder
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144609251, Jennifer Sabourin
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3007154, Lucy R. Shores
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145508283, Daniil Kononenko
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1399291986, Kiyoko F. Aoki-Kinoshita
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144718788, L. Deng
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145890221, A. Alwan
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2157241745, Yanyi Chen
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3185110, Robert Pruvenok
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_48190770, S. Momen
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_153446958, W. Kew
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1988489309, J. Mitchell
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_143628853, Elizabeth LaPensée
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_52615500, J. Wheatley
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1684457, M. Dunham
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2701127, S. Schewe
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2690172, Diana Sungatullina
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1718571, F. Henskens
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1938133, Michael Hannaford
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3320620, B. Alom
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2078607, Roberto Zampolini
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145553355, E. Gordon
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_49401455, L. Konopka
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2805650, S. Lau
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_34905047, Rikke Magnussen
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2320954, Audrey Girouard
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_50488319, Paden Shorey
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1683669, L. Deri
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1875442, Valeria Lorenzetti
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2093463872, Steve Mortimer
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1767692, K. Opwis
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1960450, Elisa D. Mekler
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_50053016, Sarah I. Endress
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_98232539, J. Benthem
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_144989167, A. Flory
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_47531065, Madjid Meziane
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1571154002, I. Kalinina
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1680621, U. Büker
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_9210928, B. Mertsching
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_28354393, A. Gozhyj
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_9077801, V. Vysotska
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_31323598, Dany Laksono
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1713331, Antonios Liapis
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_48630276, Amy K. Hoover
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2069452458, T. Tan
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2069946935, S. M. Goh
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1766832, U. Engelke
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_3270882, T. M. Kusuma
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_48546175, H. Zepernick
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2507796, S. Thorne
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_52367308, Ravi Purushotma
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_116150522, Ioanna Vasileiadou
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_145188857, A. Elmagarmid
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2112625845, Paul Cheng
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_1740145, V. Lempitsky
# http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#Author_2871176, Takashi Ui
# Results have been printed.

# %% [markdown]
# ## 2. Find all properties whose domain is Author.

# %%
# Define the SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

SELECT DISTINCT (strafter(str(?property), "#") AS ?propertyName)
WHERE {
  # ?property rdfs:domain ex:Author .
}
"""

# Set the query and format
sparql.setQuery(query)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Print the results directly
print("Properties with Domain as Author:")
for result in results["results"]["bindings"]:
    propertyName = result["propertyName"]["value"]
    print(propertyName)

print("Results have been printed.")
# Out:
# Properties with Domain as Author:
# affiliated_with
# author_email
# author_id
# author_name
# Results have been printed.

# %% [markdown]
# ## 3. Find all properties whose domain is either Conference or Journal.

# %%
# Define the SPARQL query to find properties whose domain is either Conference or Journal
query_properties = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

SELECT DISTINCT ?property
WHERE {
  # ?property rdfs:domain ?domain .
  FILTER (?domain IN (ex:Conference, ex:Journal))
}
"""

# Set the query and format
sparql.setQuery(query_properties)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Print the results directly
print("Properties with domain as Conference or Journal:")
prefix_to_remove = "http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#"
if not results["results"]["bindings"]:
    print("No properties found for Conference or Journal.")
else:
    for result in results["results"]["bindings"]:
        property_uri = result["property"]["value"]
        property_name = property_uri.replace(prefix_to_remove, "")
        print(f"Property: {property_name}")
# Out:
# Properties with domain as Conference or Journal:
# Property: city
# Property: edition
# Property: conference_year
# Property: conference_id
# Property: conference_name
# Property: conference_url
# Property: volume
# Property: journal_year
# Property: issn
# Property: journal_id
# Property: journal_name
# Property: journal_url

# %% [markdown]
# ## 4. Find all the papers written by a given author that where published in database conferences.

# %%
# Define the SPARQL query to list all authors and their names
query_authors = """
  PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
  PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>

  SELECT DISTINCT ?property 
  WHERE 
  { 
    # ?property rdfs:domain ?domain .
    # ?domain rdfs:subClassOf ex:Proceeding .
  }
"""

# Set the query and format
sparql.setQuery(query_authors)
sparql.setReturnFormat(JSON)

# Execute the query and process results
results = sparql.query().convert()

# Print the results directly
print("List of Authors and their URIs:")
if not results["results"]["bindings"]:
    print("No authors found.")
else:
    for result in results["results"]["bindings"]:
        author_uri = result["author"]["value"]
        author_name = result["name"]["value"]
        print(f"Author URI: {author_uri}, Name: {author_name}")
# Out:
# List of Authors and their URIs:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 24>()
#      26 else:
#      27     for result in results["results"]["bindings"]:
# ---> 28         author_uri = result["author"]["value"]
#      29         author_name = result["name"]["value"]
#      30         print(f"Author URI: {author_uri}, Name: {author_name}")
#
# KeyError: 'author'

# %% [markdown]
# ## Additional Query: 5. Authors with Most Publications Across Different Conferences and Journals

# %%
# Define the modified query
query = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?authorName ?venueName (COUNT(?paper) AS ?totalPapers)
WHERE {
  # ?paper ex:written_by ?author .
  # ?author foaf:name ?authorName .
  # ?paper ex:published_in ?venue .
  # ?venue ex:name ?venueName .
}
GROUP BY ?authorName ?venueName
ORDER BY DESC(?totalPapers)
"""

# Function to run the query
def run_query(query):
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return pd.json_normalize(results['results']['bindings'])

# Function to format the results
def format_results(df):
    # Extract necessary fields
    df = df[['authorName.value', 'venueName.value', 'totalPapers.value']]
    # Rename columns
    df.columns = ['Author Name', 'Venue Name', 'Total Papers']
    # Convert values to appropriate types
    df['Total Papers'] = df['Total Papers'].astype(int)
    return df

# Execute the query and get the results
df = run_query(query)

# Format the results
formatted_df = format_results(df)

# Save the results to a CSV file
formatted_df.to_csv('/turtle2/4_5.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 38>()
#      35 df = run_query(query)
#      37 # Format the results
# ---> 38 formatted_df = format_results(df)
#      40 # Save the results to a CSV file
#      41 formatted_df.to_csv('/turtle2/4_5.csv', index=False)
#
# Input In [6], in format_results(df)
#      25 def format_results(df):
#      26     # Extract necessary fields
# ---> 27     df = df[['authorName.value', 'venueName.value', 'totalPapers.value']]
#      28     # Rename columns
#      29     df.columns = ['Author Name', 'Venue Name', 'Total Papers']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['authorName.value', 'venueName.value', 'totalPapers.value'], dtype='object')] are in the [columns]"

# %% [markdown]
# ## Additional Query: 6. Trend Analysis: Growth in Paper Publications Over Years by Topic

# %%
query2 = """
PREFIX ex: <http://www.semanticweb.org/kocak/ontologies/2024/4/AcademicPapers#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?year (SAMPLE(?keyword) AS ?sampleKeyword) (COUNT(?paper) AS ?totalPapers)
WHERE {
  # ?paper ex:year ?year ;
         ex:keywords ?keywords .
  BIND(STRAFTER(?keywords, ",") AS ?keyword)  # Assuming keywords are separated by commas
}
GROUP BY ?year ?keyword
ORDER BY ?year
"""

# Function to run the query
def run_query(query):
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return pd.json_normalize(results['results']['bindings'])

# Function to format the results
def format_results(df):
    # Extract necessary fields
    df = df[['year.value', 'sampleKeyword.value', 'totalPapers.value']]
    # Rename columns
    df.columns = ['Year', 'Sample Keyword', 'Total Papers']
    # Convert values to appropriate data types
    df['Year'] = df['Year'].astype(int)
    df['Total Papers'] = df['Total Papers'].astype(int)
    return df

# Execute the query and get the results
df2 = run_query(query2)

# Format the results
formatted_df2 = format_results(df2)

# Save the formatted results to a CSV file
formatted_df2.to_csv('4_6.csv', index=False)

# Print the results in a readable format
print("Publications by Year with Sample Keywords:")
print(formatted_df2.to_string(index=False))
# Out:
# Publications by Year with Sample Keywords:
#  Year                                                                                                                                                                               Sample Keyword  Total Papers
#  1978                                                                                                                                                                                                          9
#  1986                                                                                                                                                                                                          9
#  1987                                     main,database,systems,performance,recovery,declining,cost,need,high,recently,spired,research,massive,amounts,ability,store,complete,databases,recognized             9
#  1987                         learning,team,problems,elements,competition,cooperation,present,game,stochastic,automata,adaptive,behavior,theoretical,neural,often,described,terms,approach,network             9
#  1988                                                     semantics,dataloga,logic,updates,datalog,w,p,states,show,need,control,recognized,particularly,evident,one,focuses,allowing,paper,propose             9
#  1989           experimental,work,cryptographic,protection,databases,software,database,experiment,natural,language,dictionary,spanish,verbs,tentative,conclusion,overhead,cost,computing,encrypted             9
#  1990                                                                                                                                                                                                          9
#  1991                                                    tutorial,due,interbase,notes,based,issue,title,also,book,special,acknowledgements,march,ieee,data,engineering,edited,author,upcoming,come             9
#  1992                                   classroom,uses,computer,central,knowledge,design,scardamalia,bereiter,communal,database,play,important,role,educational,experiments,levin,riel,use,article             9
#  1992                                                                                                                                                                                                          9
#  1993                                                                                                                                                                                                          9
#  1995                     databases,database,interoperation,different,dbs,components,query,interactive,vision,infrastructure,provide,number,describes,among,module,access,translators,data,realize             9
#  1995                transformation,hierarchical,parallel,algorithms,structures,recognition,traffic,illustrated,analysis,paper,presents,efficient,evaluation,maps,onto,code,trees,different,height             9
#  1996                                                                                                                                                                                                         18
#  1997                                                                                                                                                                                                          9
#  1998         coordination,subsystems,properties,application,technology,agent,guarantees,database,functionality,advanced,c,simulation,councils,cim,means,enforcing,dependencies,autonomous,propose             9
#  1998                                                                                                                                                                                                          9
#  1999                                features,semantic,image,retrieval,complex,similarity,queries,describing,information,index,mechanism,support,three,visual,keywords,signature,file,hashing,also             9
#  1999                                                                                                                                                                                                          9
#  2000                                game,knowledge,educational,games,relationship,study,nutrition,label,methods,board,abstract,last,several,decades,increase,development,use,classroom,literature             9
#  2000                                          games,function,shapley,gain,game,cooperative,indexed,set,strategy,abstract,considered,monderer,econom,player,deviation,equal,prove,payoff,functions             9
#  2000                                                                                                                                                                                                          9
#  2000                                                                                                                                       existence,maxmin,recursive,games,one,sided,information             9
#  2001                                    reasoning,paper,waypoint,graph,discusses,presents,based,typically,present,action,games,concepts,reasoned,demonstrates,relation,tactics,shows,develop,pick             9
#  2002                                                                                                                                                                                                         18
#  2002                               data,database,query,multiple,nodes,seek,workload,optimal,physical,design,important,parallel,system,horizontally,partitioned,among,independent,automate,process             9
#  2002                                                                                       paper,proposes,conceptual,framework,examining,computer,structure,applies,massive,multiplayer,everquest             9
#  2003                                                                                                                                                                                                         27
#  2003                                                                            logic,analyze,games,bringing,together,two,viewpoints,jaakko,hintikka,work,semantics,epistemic,process,link,theory             9
#  2003            results,information,retrieval,returning,relevant,query,popular,paradigm,discuss,challenges,investigate,several,approaches,enable,databases,including,adaptations,known,techniques             9
#  2004                                    describe,use,pharmacophore,modeling,efficient,tool,discovery,novel,integrase,hypothetical,model,binding,diketo,acid,analogues,enzyme,built,means,catalyst             9
#  2004                                            database,data,resources,blast,genbank,retrieval,entrez,pubmed,tools,viewer,conserved,domain,addition,maintaining,r,nucleic,acid,sequence,national             9
#  2004   information,processing,applications,systems,queries,need,database,techniques,spatial,nearest,neighbor,modern,computationally,intensive,require,storage,manipulation,voluminous,traditional             9
#  2005                                                    science,game,homicide,active,process,inquiry,paper,present,first,test,forensic,experts,recent,years,education,focus,study,development,new             9
#  2005                                                                                                                                                                                                         36
#  2005                                              storage,presents,helps,developers,models,paper,design,implement,owl,ontologies,uses,xml,represent,knowledge,given,ontology,deﬁne,rules,generate             9
#  2005                                               scheduling,use,learning,ml,cpu,behavior,programs,linux,analysis,static,dynamic,attributes,processes,process,tat,context,execution,work,machine             9
#  2005                          performance,security,database,data,must,level,protect,sensitive,provide,techniques,alternative,topologies,complex,used,environment,expertise,strong,rest,developing             9
#  2005                                                  relational,semantic,query,databases,using,access,sql,web,applications,still,unable,stored,functionality,hence,needing,fall,back,model,paper             9
#  2005                                                  et,eeg,clinical,also,neuroscience,data,database,al,brain,development,well,provide,across,article,issue,individual,science,potential,methods             9
#  2005                                                                       games,discrete,time,survey,recent,results,value,zerosum,stopping,continuous,non,abstract,borrowed,another,version,item             9
#  2006                                  session,examinations,material,student,learning,classroom,instructors,students,may,even,conduct,often,serve,primary,means,assess,within,environment,increase             9
#  2006                     present,mdps,probabilistic,practical,nondeterminism,mdp,paper,novel,technique,markov,decision,processes,widely,used,modelling,systems,exhibit,nondeterministic,behaviour             9
#  2006                                                                                                                                                                                                          9
#  2006                         game,study,methodology,interactive,devices,activities,species,describes,analyzes,design,development,application,evaluation,new,pedagogical,based,games,pdas,oriented             9
#  2006                                                                                        conflict,view,integration,complex,task,several,need,addressed,two,identification,resolution,conflicts             9
#  2006                                   games,assignments,students,projects,game,computer,introductory,results,course,option,average,provide,motivation,often,cited,motivational,tool,used,courses             9
#  2006                                         corpus,paper,recorded,based,synthesis,emotions,creation,describes,emotional,speech,standard,basque,designed,twofold,purpose,used,also,allowing,study             9
#  2006                                        game,nash,players,model,source,potential,function,consider,player,minimizes,cost,fractional,prove,multicast,selfish,models,integral,finding,existence             9
#  2006                                      speech,database,vocal,tract,resonances,processing,automatic,techniques,frequency,phonetic,values,cv,vc,transitions,tracking,vtrs,formants,defined,known             9
#  2007                                                                                                                                                                                                         18
#  2007                                                     capture,data,database,sequence,provide,words,symbols,humanoid,also,paper,patterns,similar,model,input,analogy,systems,used,obtain,robots             9
#  2007                          nodes,autonomic,networks,costs,games,depend,functionalities,even,modeled,selfish,gain,sense,accomplish,functionality,performance,impossible,achieve,without,however             9
#  2007                               case,students,develop,business,queries,detect,query,details,plan,data,operations,appropriate,process,diagram,understand,situation,create,billing,discrepancies             9
#  2007                                     configuration,optimal,users,game,usability,network,method,based,strategy,systems,individual,make,trade,tems,important,issue,resolve,problem,optimization             9
#  2007             platform,game,factory,proposed,paper,presents,environment,targeted,games,development,industrialization,product,line,definition,architecture,specified,implemented,means,software             9
#  2007                      situations,superior,jamming,confrontation,approach,strategy,existing,pe,game,algorithms,provide,good,solutions,following,complexities,multiple,control,resources,higher             9
#  2007                                      low,high,condition,games,interdependency,fun,flow,performance,online,mmorpgs,interaction,features,design,conditions,higher,also,obtained,today,millions             9
#  2007                                 game,often,interactivity,gameplay,many,games,narrative,ways,agency,cinema,within,since,cutscene,interactive,new,conceptions,cinematic,representation,current             9
#  2007      transporters,analysis,sequences,number,use,transporter,tripartite,periplasmic,family,extracytoplasmic,solute,secondary,widespread,prokaryotic,world,extensively,studied,present,results             9
#  2008                     numerical,stochastic,differential,new,proof,provided,convergence,paper,concerned,games,diffusions,using,markov,chain,approximation,techniques,developed,existence,saddle             9
#  2008           bacterial,databases,providing,burkholderia,species,information,research,community,database,contains,summary,sequences,multiple,strains,given,obtained,generalized,may,complemented             9
#  2008                                      gaze,use,humans,information,intentions,actions,sclera,interpretation,extends,show,also,control,user,human,beings,communicate,abbreviated,ways,dependent             9
#  2008                                         qos,users,providers,grid,performance,jobs,solution,computing,nodes,acceptable,customers,game,job,allocation,problem,differs,traditional,high,systems             9
#  2008                         one,game,subjects,acknowledgments,national,science,foundation,texas,advanced,research,program,financial,support,faculty,development,leave,university,pittsburgh,time             9
#  2009                      games,observation,equivalence,consider,general,hybrid,systems,dynamics,system,players,partial,show,suffix,encoding,abstraction,decidability,computability,results,paper             9
#  2009                                                                                                                                                                                                         36
#  2009                                               historical,game,gaming,chapter,potential,around,one,developed,two,orienting,experience,system,forms,examines,video,games,tool,given,productive             9
#  2009                              table,data,relationship,digital,blueprints,company,view,forensics,field,obtain,evidences,extraction,organizations,manage,personnel,account,logistics,etc,system             9
#  2009                                             creative,development,performance,neural,two,field,n,group,behaviour,types,networks,programme,learning,groups,soccer,hockey,p,fluctuation,process             9
#  2009                                   strategies,abstract,game,large,size,approach,extensive,recent,increasing,solved,computing,original,resulting,strategy,found,larger,expressive,method,often             9
#  2010                system,technique,distributed,detection,optimization,presented,problem,database,algorithm,transactions,cycles,local,global,really,one,serious,problems,multitasking,concurrent             9
#  2010                 model,information,new,security,particular,propose,approach,theory,defense,challenges,significant,advances,technology,infrastructure,offer,opportunities,cyberspace,still,far             9
#  2010                                              system,ar,immersive,vr,developed,environments,reality,users,world,players,evaluation,paper,present,new,multiplayer,two,different,namely,virtual             9
#  2010                                                                                                                                                                                                         27
#  2010                             archives,article,scholars,database,ways,databases,memory,category,include,inventory,study,construction,move,toward,within,recent,attempts,practitioners,curators             9
#  2010                                              databases,database,mos,objective,available,image,experiments,prediction,models,made,paper,wireless,wiq,test,images,mean,opinion,scores,obtained             9
#  2011                                   information,culture,reputation,algorithm,collusive,group,sources,systems,game,special,pattern,profit,distribution,state,web,allow,aggregate,many,heritages             9
#  2011                                databases,language,natural,information,sql,development,intelligent,nlidb,systems,major,almost,retrieving,languages,query,relational,queries,system,idbs,users             9
#  2011                femtocell,macrocell,pricing,interference,scenario,resource,allocation,networks,distributed,femtocells,mbs,stackelberg,two,deployed,areas,schemes,effective,paper,investigates             9
#  2011                                                      upper,case,players,lower,bounds,bound,price,stability,number,multicast,broadcast,new,improved,ref,almost,seven,years,undirected,network             9
#  2011                                databases,data,us,firms,innovation,use,public,comets,technology,database,sciences,technologies,organization,individual,covering,include,patents,web,knowledge             9
#  2011                                                                                                                                                                                                         18
#  2011 student,accounting,active,use,feedback,students,provide,technology,technological,immediate,stakeholders,encourage,educators,opportunities,integrate,creative,curriculum,emphasize,principles             9
#  2011                                       games,software,engineering,model,teaching,benefits,quality,expected,several,various,already,developed,context,yet,still,lack,assessment,models,measure             9
#  2012                                                       worlds,pearce,game,online,players,emergent,virtual,book,mmo,prologue,group,behavior,second,one,world,live,affordances,communities,play             9
#  2012                                         relational,databases,mappings,patterns,order,rdf,two,paper,integrate,semantic,web,applications,need,mapped,working,group,process,ratifying,standards             9
#  2012                                                                                                                                                                                                         27
#  2012                                                 rgd,data,term,search,browser,terms,ontology,database,human,qtls,strains,biological,information,ontologies,upgraded,tree,format,allows,report             9
#  2012               updates,games,model,resources,consumption,every,number,player,problems,introduceconsumption,discrete,interactive,system,multiple,consumed,reloade,independently,precisely,game             9
#  2013                                                                                                                                                                                                         36
#  2013                                         game,number,poker,actions,size,states,decision,points,estimated,information,algorithm,eld,computational,theory,often,compared,terms,measured,several             9
#  2013                                                         mqn,using,molecular,virtual,screening,lbvs,cbd,analogs,universe,database,contains,billion,molecules,atoms,c,n,halogens,obeying,rules             9
#  2014                                     patrol,traffic,stackelberg,game,games,police,present,streets,problem,strategies,work,counterterrorism,first,process,novel,solving,modeling,using,patrols             9
#  2014                    tools,users,data,causality,explanation,applications,database,surge,availability,information,great,demand,assist,understanding,today,exploration,rely,mostly,visualization             9
#  2014                                                digital,physical,game,design,education,learning,games,attention,principles,play,could,coach,teacher,within,learn,way,capture,sustain,maintain             9
#  2014                              level,technique,calculation,metrics,events,siem,allows,attack,system,analysis,risks,important,task,information,management,systems,recognizing,current,situation             9
#  2014                                        players,collaborative,design,game,patterns,also,player,interactions,cooperative,became,popular,recent,years,aside,received,well,great,offer,potential             9
#  2014                                      bci,devices,entertainment,applications,brain,research,production,et,al,work,conscious,reliability,commercial,computer,interface,lower,cost,systems,well             9
#  2014                                       risk,among,children,use,sedentary,behaviors,adolescents,computer,game,aor,effect,physical,interventions,studies,relationship,show,mixed,results,fourth             9
#  2014                learning,systems,machine,computational,models,human,online,modeling,approaches,techniques,problem,provides,detailed,introduction,concept,application,various,computer,science             9
#  2015                                 methods,performance,linear,greedy,best,method,machine,learning,methodology,data,problems,perform,found,single,application,cheminformatics,large,active,field             9
#  2015                                    perfect,strategies,effect,subjects,noisy,public,private,across,paper,uses,laboratory,experiment,study,structure,play,infinitely,repeated,prisoner,dilemma             9
#  2015                               nvd,data,vulnerabilities,security,vulnerability,information,applications,one,time,next,various,prediction,suggest,abstract,major,cause,cyber,problems,national             9
#  2015                                     fusion,byzantines,optimum,nodes,fc,behavior,system,provided,local,permits,performance,cases,presence,malicious,often,referred,hindered,necessity,exactly             9
#  2015                               users,game,enterprise,gamified,dynamics,activities,engagement,ideas,theory,model,influence,whereby,engaged,induced,elements,gaining,interest,among,researchers             9
#  2015                            animations,disciplines,concepts,many,computer,fundamental,courses,well,evaluation,topics,technology,affects,beyond,science,business,paper,describes,two,developed             9
#  2015                                                                                                                                                                                                         18
#  2015                                     management,data,systems,bigdata,conventional,tools,rdbms,observed,utility,study,nosql,traditional,growing,fast,becoming,complex,volume,terabyte,petabyte             9
#  2015                                                                                                      computer,simulated,user,scenarios,used,means,facilitate,process,explore,reveal,possible             9
#  2015                                             plant,mirlocator,mature,mirna,class,locating,within,algorithm,machine,learning,prediction,species,micrornas,short,rna,play,regulatory,roles,wide             9
#  2016                          datasets,videoqa,using,videos,reasoning,events,various,video,synthetic,constructed,automatically,gameplay,existing,often,temporal,dataset,levels,complexity,present             9
#  2016                                   recognition,player,modeling,digital,games,problem,networks,recent,years,seen,growing,interest,aims,accurately,recognize,players,goals,observations,actions             9
#  2016                                                                                                                                                                                                         27
#  2016                  warfare,modelling,scenarios,games,research,autonomous,systems,important,humans,machines,game,theory,role,increasing,dependence,technologies,escalated,international,concern             9
#  2017                               databases,research,emotion,past,decades,interaction,become,important,daily,lives,developed,many,directions,memory,depression,behavioural,deficiency,lie,hidden             9
#  2017                                leader,stackelberg,pp,control,three,stochastic,functional,differential,equations,article,consider,mean,field,dominating,player,group,followers,agents,setting             9
#  2017                           english,language,students,computer,games,learning,grade,young,particularly,learn,national,curriculum,upon,results,purpose,investigate,effectiveness,foreign,extent             9
#  2017                                        design,patterns,user,used,games,game,emotional,state,new,dimension,interaction,improve,experience,domain,computing,work,focus,applications,techniques             9
#  2017                                                                                                                                                                                                         18
#  2017                                    model,games,software,game,industry,possible,reliability,checking,approach,method,multiplayer,play,big,role,entertainment,competitive,means,releasing,best             9
#  2017                                                               control,using,study,scheme,input,games,deformation,button,one,tested,simple,schemes,binary,action,two,game,mapped,best,results             9
#  2018                                                                                                                                                                                                         27
#  2018                                                 geospatial,big,databases,sql,nosql,database,handling,postgis,mongodb,large,amount,better,storing,performance,test,loading,result,last,decade             9
#  2018            information,framework,sharing,proposed,blockchain,bitcoin,transactions,public,ledger,organizations,paper,design,develop,evaluate,novel,cybersecurity,goal,protecting,confidential             9
#  2018                                         di,database,documents,management,projects,tools,use,storage,nlp,automatic,text,analysis,necessarily,involve,annotation,natural,language,texts,apache             9
#  2018                                   posture,system,children,postures,algorithms,chair,postural,habit,childhood,monitoring,classifying,machine,neural,network,cnn,algorithm,data,cushion,sensor             9
#  2018                                graph,query,data,present,approach,execution,queries,databases,system,server,copyright,scitepress,science,technology,publications,lda,rights,reserved,inspired             9
#  2018                                       based,system,redirection,images,training,problem,idea,monocular,systems,decision,correction,second,deep,third,teacher,network,propose,general,approach             9
#  2019                                                                                                                                                                                                         18
#  2019                                    uncertainty,directions,information,mahjong,chess,games,gr,study,noble,paper,presents,two,evolution,using,multiplayer,incomplete,complete,show,transitions             9
#  2019                                      feynman,diagrams,use,present,str,relations,mathematica,designed,solve,integrals,means,method,uniqueness,euclidean,spacetime,dimension,provide,set,tools             9
#  2019              methodology,design,designers,solutions,inspiration,nmf,repositories,dba,method,repository,retrieve,computational,content,proposed,hierarchical,test,important,innovation,gained             9
#  2019                            students,declarative,serious,emerge,procedural,game,measured,questions,background,games,working,teaching,medical,assessed,satisfaction,use,objective,study,effect             9
#  2020                         utilizing,prove,perspectives,academical,interactive,game,education,story,results,concepts,applied,ethics,responsible,conduct,research,difficult,teach,due,complexity             9
#  2020                                                                                                                                                                                                         18
#  2020                                 data,iot,amount,two,database,huge,evaluating,dbmss,mysql,mongodb,performance,resources,specifications,size,challenge,sensors,heterogeneous,needs,appropriate             9
#  2020                                         dataset,iemocap,feature,study,wa,reliable,ser,mel,spectrogram,reliability,proposed,improvised,results,propose,recognition,long,memory,lstm,component             9
#  2020                                                   pieces,bardo,composer,system,identify,generated,paper,generate,music,uses,speech,model,stochastic,beam,search,study,able,correctly,present             9
#  2021                      disease,laboratory,testing,data,ml,medicine,multiple,approaches,provide,applications,machine,learning,platforms,clinical,human,limitations,streams,including,actionable             9
#  2021                                                   insect,using,nir,inputs,r,predict,data,coupled,machine,learning,ml,system,presence,paper,results,developed,based,classification,regression             9
#  2021                                                                                                                                                                                                          9
#  2022                 structure,predictions,alphafold,arguably,year,achieving,previously,unseen,accuracy,critical,assessment,prediction,casp,deepmind,developed,database,make,unprecedented,number             9
#  2022                                                      fake,knowledge,media,detection,social,due,helpful,help,proposed,different,spread,days,society,knew,machine,learning,us,data,engineering             9
#  2022                                         databases,update,pruw,submodel,problem,given,constraint,scheme,total,cost,investigate,private,read,write,relation,federated,learning,fsl,constrained             9
#  2022                                              radar,restroom,using,system,behaviors,doppler,machine,methods,results,human,learning,including,cnn,data,features,accuracy,fall,monitoring,study             9
#  2023                       financial,machine,deep,algorithms,models,price,prediction,analysis,stock,sector,traders,instrument,forecasting,review,article,ensemble,classification,provides,greatly             9
# /var/folders/h2/xxz9whrn7m30c5fnlbnywhmh0000gn/T/ipykernel_19518/3132669228.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].astype(int)
# /var/folders/h2/xxz9whrn7m30c5fnlbnywhmh0000gn/T/ipykernel_19518/3132669228.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Papers'] = df['Total Papers'].astype(int)
